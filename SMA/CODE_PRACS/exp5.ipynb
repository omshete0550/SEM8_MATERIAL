# %% [markdown]
# 5	Sentiment Analysis for given dataset
# •	Negative Sentiment analysis
# •	Positive Sentiment analysis

# %%
import pandas as pd
from textblob import TextBlob
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("CSV/sentiment.csv")
df.head()
# Out:
#                                        text     label
# 0                      I love this product!  positive
# 1                  This movie was terrible.  negative
# 2           I can't wait to go on vacation!  positive
# 3            Traffic today was a nightmare.  negative
# 4  The food at this restaurant was amazing!  positive

# %%
df["polarity"] = df["text"].apply(lambda x: TextBlob(x).sentiment.polarity)
print(df.head())
# Out:
#                                        text     label  polarity
# 0                      I love this product!  positive     0.625
# 1                  This movie was terrible.  negative    -1.000
# 2           I can't wait to go on vacation!  positive     0.000
# 3            Traffic today was a nightmare.  negative     0.000
# 4  The food at this restaurant was amazing!  positive     0.750

# %%
ans = []
for i in df["polarity"]:
  print(i)
  if i>0.5:
    ans.append("positive")
  else:
    ans.append("negative")

df["pred"] = ans
# Out:
# 0.625
# -1.0
# 0.0
# 0.0
# 0.7500000000000001
# -0.4
# 1.0
# 0.0
# 0.45
# -0.8

# %%
print(df.head())
# Out:
#                                        text     label  polarity      pred
# 0                      I love this product!  positive     0.625  positive
# 1                  This movie was terrible.  negative    -1.000  negative
# 2           I can't wait to go on vacation!  positive     0.000  negative
# 3            Traffic today was a nightmare.  negative     0.000  negative
# 4  The food at this restaurant was amazing!  positive     0.750  positive

# %%
pos_tweets = df[df["label"] == "positive"]
neg_tweets = df[df["label"] == "negative"]

# %%
sns.kdeplot(pos_tweets["polarity"], shade=True, label="Positive")
sns.kdeplot(neg_tweets["polarity"], shade=True, label="Negative")
plt.xlabel("Polarity Score")
plt.ylabel("Density")
plt.title("Sentiment Analysis of Tweets")
plt.legend()
plt.show()

# %%
ans = []
for i in df["polarity"]:
  if i>0.1:
    ans.append("positive")
  elif(i<-0.1):
    ans.append("negative")
  else:
    ans.append("neutral")

df["sentiment"] = ans

# %%
sentiment_counts = df['sentiment'].value_counts()
print(sentiment_counts)
# Out:
# sentiment
# positive    4
# negative    3
# neutral     3
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x=sentiment_counts.index, y=sentiment_counts.values, palette="viridis")
plt.xlabel('Sentiment')
plt.ylabel('Number of Tweets')
plt.title('Sentiment Analysis')
plt.show()
# Out:
# C:\Users\Om Shete\AppData\Local\Temp\ipykernel_32544\4273826408.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=sentiment_counts.index, y=sentiment_counts.values, palette="viridis")

# %%
df["label"]
# Out:
# 0    positive
# 1    negative
# 2    positive
# 3    negative
# 4    positive
# 5    negative
# 6    positive
# 7    negative
# 8    positive
# 9    negative
# Name: label, dtype: object

# %%
pos_tweets = df[df["sentiment"] == "positive"]
neg_tweets = df[df["sentiment"] == "negative"]
neutral_tweets = df[df["sentiment"] == "neutral"]

# %%
print("Positive Tweets:")
for tweet in pos_tweets['text'].head():
  print("-", tweet)

print("\nNegative Tweets:")
for tweet in neg_tweets['text'].head():
  print("-", tweet)

print("\nNeutral Tweets:")
for tweet in neutral_tweets['text'].head():
  print("-", tweet)
# Out:
# Positive Tweets:
# - I love this product!
# - The food at this restaurant was amazing!
# - Great workout at the gym today!
# - Spent the day at the beach with my family, it was perfect!
#
# Negative Tweets:
# - This movie was terrible.
# - I'm so tired of this rain.
# - I hate when my flight gets delayed.
#
# Neutral Tweets:
# - I can't wait to go on vacation!
# - Traffic today was a nightmare.
# - Ugh, another meeting.

# %%
sns.kdeplot(pos_tweets["polarity"], shade=True, label="Positive")
sns.kdeplot(neg_tweets["polarity"], shade=True, label="Negative")
sns.kdeplot(neutral_tweets["polarity"], shade=True, label="Neutral")
plt.xlabel("Polarity Score")
plt.ylabel("Density")
plt.title("Sentiment Analysis of Tweets")
plt.legend()
plt.show()
# Out:
# C:\Users\Om Shete\AppData\Local\Temp\ipykernel_32544\738830587.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(pos_tweets["polarity"], shade=True, label="Positive")
# C:\Users\Om Shete\AppData\Local\Temp\ipykernel_32544\738830587.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(neg_tweets["polarity"], shade=True, label="Negative")
# C:\Users\Om Shete\AppData\Local\Temp\ipykernel_32544\738830587.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(neutral_tweets["polarity"], shade=True, label="Neutral")
# C:\Users\Om Shete\AppData\Local\Temp\ipykernel_32544\738830587.py:3: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(neutral_tweets["polarity"], shade=True, label="Neutral")
