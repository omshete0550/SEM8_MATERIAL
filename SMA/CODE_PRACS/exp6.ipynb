# %% [markdown]
# 6. User engagement analysis: analyze how users engage with content on social media to understand what types of content are most engaging

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Tweets.csv")

# %%
# Group by sentiment and calculate average retweets
avg_retweets_by_sentiment = df.groupby('airline_sentiment')['retweet_count'].mean().sort_values(ascending=False)

# Plot
avg_retweets_by_sentiment.plot(kind='bar', color=['green', 'blue', 'red'])
plt.title("Average Retweets by Sentiment")
plt.ylabel("Average Retweet Count")
plt.xlabel("Sentiment")
plt.xticks(rotation=0)
plt.show()

# %%
# Average retweet count per airline
avg_retweets_by_airline = df.groupby('airline')['retweet_count'].mean().sort_values(ascending=False)

# Plot
avg_retweets_by_airline.plot(kind='bar', color='skyblue')
plt.title("Average Retweets per Airline")
plt.ylabel("Average Retweet Count")
plt.xlabel("Airline")
plt.xticks(rotation=45)
plt.show()

# %%
# Add a new column for text length
df['text_length'] = df['text'].astype(str).apply(len)

# Scatter plot
plt.scatter(df['text_length'], df['retweet_count'], alpha=0.5)
plt.title("Tweet Length vs Retweets")
plt.xlabel("Text Length")
plt.ylabel("Retweet Count")
plt.show()

# %%
top_engaged_tweets = df.sort_values(by='retweet_count', ascending=False)[['text', 'retweet_count']].head(5)
print(top_engaged_tweets)
# Out:
#                                                     text  retweet_count
# 11596  @USAirways 5 hr flight delay and a delay when ...             44
# 11582  @USAirways of course never again tho . Thanks ...             32
# 7132   STOP. USING.THIS.WORD. IF. YOU'RE. A. COMPANY....             31
# 9999   @USAirways with this livery back in the day. h...             28
# 5607   @SouthwestAir beautiful day in Seattle! http:/...             22
